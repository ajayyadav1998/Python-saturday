# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\lib\pretty.py:697: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   output = repr(obj)
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
# ...

# %%
x = np.linspace(0,5,11) #start ,stop ,value

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x **2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.figure(figsize=(10,5),facecolor='red')
plt.rcParams['text.color'] = 'green'
plt.plot(x,y,'k',marker='o',markeredgecolor='red',markersize=10)
plt.title('graph of x,y linspace')
plt.xlabel('x-axis',fontdict={'color':'g','fontsize':20})
plt.ylabel('y-axis',fontdict={'color':'g','fontsize':20})
plt.show()

# %%
plt.figure(figsize=(10,5),facecolor='#800080')
plt.plot([1,2,3,4,5],[1,4,9,16,25],'r^')
plt.plot([1,4,9,16,25],[1,2,3,4,5],'go')
plt.show()

# %%
plt.rcParams['text.color'] = 'black'
plt.subplot(1,2,1) #rows,coloumns,access number
plt.plot(x,y,'r--')
plt.title('first graph')

plt.subplot(1,2,2)
plt.plot(y,x,'m--')
plt.title('Second graph')

plt.tight_layout()

# %%
fig = plt.figure(figsize=(10,5),facecolor='#ff9999')

ax1 = fig.add_axes([0,0,0.9,0.9]) #left,bottom,width,height
ax2 = fig.add_axes([0.1,0.35,0.4,0.4])

ax1.plot(x,y,'y--')
ax1.set_title('large graph')
ax1.set_xlabel('x-axis')
ax1.set_ylabel('y-axis')


ax2.plot(y,x,'k--')
ax2.set_title('small graph')
ax2.set_xlabel('x-axis')
ax2.set_ylabel('y-axis')
plt.show()

# %%
fig,ax = plt.subplots(ncols=2,nrows=2,figsize=(10,5))
plt.suptitle('subplots')

ax[0,0].plot([1,2,3,4,5],[1,4,9,16,25],'k--')
ax[0,1].plot([1,2,3,4],[5,6,3,8],'r--')
ax[1,1].plot(x,y,'m--')
ax[1,0].plot(y,x,'y--')

plt.show()

# %%
height = np.random.randint(140,200,20)
weight = np.random.randint(60,80,20)

# %%
len(height) == len(weight)
# Out:
# True

# %%
from mpl_toolkits import mplot3d

# %%
plt.figure(figsize=(10,5))
ax = plt.subplot(projection='3d')
ax.scatter3D(height,weight)
ax.set_title('3D graph')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
plt.show()

# %%
random  = np.random.randint(1,1000,1000)
val = [var for var in range(1000)]

# %%
len(random)
# Out:
# 1000

# %%
len(val)
# Out:
# 1000

# %%
len(random) == len(val)
# Out:
# True

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=random,y=val)
plt.show()

# %%
players = ['virat','sachin','nikhil','dev','rishi','ajay','rajes']
runs = [450,530,345,345,654,445,554]
color = ['orange','pink','green','blue','red','m','yellow']
plt.figure(figsize=(10,5),facecolor='indianred')
plt.bar(x=players,height=runs,color=color,edgecolor='k')
max_r = players[runs.index(max(runs))]
plt.title('bar graph of player runs')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend([max_r],frameon=False)
#plt.show()
plt.savefig('C:/Users/Ajay/Desktop/myfig.jpg',facecolor='indianred')

# %%
x = np.linspace(0,5,11)
y = x ** 3

# %%
plt.figure(figsize=(10,5),facecolor='#ff9999')
plt.style.use('ggplot')
plt.plot([1,2,3,4,5],[1,4,9,16,25],'g',x,y,'r--',marker='o',markerfacecolor='k',markersize=10,markeredgecolor='y')
plt.title('linspace of x and y')
plt.xlabel('x-axis',fontdict={'color':'purple','fontsize':15})
plt.ylabel('y-axis',fontdict={'color':'purple','fontsize':15})
#plt.scatter(x,y,color='red')
plt.show()

# %%
x = np.linspace(-1,1,100)

# %%
plt.figure(figsize=(10,5))
plt.style.use('default')
plt.plot(x,x,'r',label='X')
plt.plot(x,x**2,'y',label='$X^2$')  # latex is used here and symbol is $$
plt.plot(x,x**3,'g',label='$X^3$')
plt.plot(x,x**4,'m',label='$X^4$')
plt.title('time pass graph')
plt.legend()
plt.show()

# %%
x = np.arange(1,30)

# %%
plt.figure(figsize=(10,5),facecolor='hotpink')
plt.plot(x,np.sin(x),color='pink',label='$Sin \Theta$')
plt.plot(x,np.cos(x),color='purple',label='$Cos \Theta$')
plt.legend(frameon=False)
plt.show()

# %%
angles = [np.deg2rad(var) for var in range(361)]

# %%
plt.figure(figsize=(10,5),facecolor='seagreen')
plt.plot(angles,np.sin(angles),'b:',lw=3,label='$Sin \Theta$')
plt.plot(angles,np.cos(angles),'g:',lw=3,label='$Cos \Theta$')
plt.title('Sin and Cos Graph')
plt.legend()
plt.show()

# %%
import time
import psutil
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.rcParams['animation.html'] = 'jshtml'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
i = 0
x,y = [],[]

while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    
    ax.plot(x,y)
    fig.canvas.draw()
    time.sleep(0.5)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-d39d38fc92e6> in <module>
#       8     ax.plot(x,y)
#       9     fig.canvas.draw()
# ---> 10     time.sleep(0.5)
#      11     i += 1
#
# KeyboardInterrupt:

# %%
plt.close()
